# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import urllib.request

# %%
def get_thumbnail_url(yt_id):
    return f"https://img.youtube.com/vi/{yt_id}/hqdefault.jpg"

def get_video_thumbnail(yt_id, folder="thumbs"):
    return urllib.request.urlretrieve(get_thumbnail_url(yt_id), f"{folder}/{yt_id}.jpg")

us_videos = pd.read_csv("Videos/USvideos.csv")
us_videos.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
def show_img(video_id, folder="thumbs"):
    img = Image.open(f"{folder}/{video_id}.jpg")
    img.show()

# %%
# importing modules
import urllib.request
from PIL import Image

video_id = us_videos.loc[0, "video_id"]

get_video_thumbnail(video_id)

show_img(video_id)

# %%
for t in range(len(us_videos)):
    video_id = us_videos.loc[t, "video_id"]
    get_video_thumbnail(video_id)
    # show_img(video_id)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_38444/1898037172.py in <module>
#       1 for t in range(len(us_videos)):
#       2     video_id = us_videos.loc[t, "video_id"]
# ----> 3     get_video_thumbnail(video_id)
#       4     # show_img(video_id)
#
# ~\AppData\Local\Temp/ipykernel_38444/3912461164.py in get_video_thumbnail(yt_id, folder)
#       3
#       4 def get_video_thumbnail(yt_id, folder="thumbs"):
# ----> 5     return urllib.request.urlretrieve(get_thumbnail_url(yt_id), f"{folder}/{yt_id}.jpg")
#       6
#       7 us_videos = pd.read_csv("Videos/USvideos.csv")
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     237     url_type, path = _splittype(url)
#     238
# --> 239     with contextlib.closing(urlopen(url, data)) as fp:
#     240         headers = fp.info()
#     241
#
# ...
