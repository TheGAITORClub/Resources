# %% [markdown]
# # Week 5

# %% [markdown]
# ## DataFrame Example

# %%
# 2D Array
some_data = [
    [6, 7, 8, 7, 3],
    [3, 4, 4, 2, 0],
    [8, 2, 7, 5, 3],
    [6, 3, 0, 9, 1]
]

# 1D Array
cols = ['col1', 'col2', 'col3', 'col4', 'col5']

df = pd.DataFrame(some_data, columns=cols)

# %%
df # <pd.DataFrame>
# Out:
#    col1  col2  col3  col4  col5
# 0     6     7     8     7     3
# 1     3     4     4     2     0
# 2     8     2     7     5     3
# 3     6     3     0     9     1

# %% [markdown]
# ## Importing Data

# %%
import pandas as pd  # https://pandas.pydata.org/docs/
import numpy as np  # https://numpy.org/doc/stable/

# %%
import os
for dirname, _, filenames in os.walk('./data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./data\data.csv

# %%
# data in this project was recieved from:
# https://www.kaggle.com/uciml/breast-cancer-wisconsin-data

path_to_csv = os.path.join(os.getcwd(), 'data', 'data.csv')
data = pd.read_csv(path_to_csv) # https://pandas.pydata.org/docs/generated/pandas.read_csv.html
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data = data.drop(['Unnamed: 32'], axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data['diagnosis'] = list(map(lambda x: 1 if x == 'M' else 0, data['diagnosis']))

# %% [markdown]
# ### Notes / Changes
#
# `0` = Benign (357 total) and `1` = Malignant (212 total)

# %%
data.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# diagnosis                569.0  3.725835e-01  4.839180e-01     0.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# ...

# %%
data['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
mal = data[data['diagnosis'] == 1]
beg = data[data['diagnosis'] == 0]

mal2 = mal.sample(n=min(len(beg), len(mal)), random_state=42)
beg2 = beg.sample(n=min(len(beg), len(mal)), random_state=42)

df = pd.concat([mal2, beg2])
df['diagnosis'].value_counts()
# Out:
# 1    212
# 0    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# # Visualize

# %%
import seaborn as sns  # https://seaborn.pydata.org/examples/index.html

grid = sns.PairGrid(df, hue='diagnosis')
grid.map_lower(sns.scatterplot)
grid.map_upper(sns.kdeplot)
grid.map_diag(sns.kdeplot, lw=3)
grid.add_legend()

# %% [markdown]
# # Preprocessing Data

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['id', 'diagnosis'], axis=1).values    # independant features
y = df['diagnosis'].values                   # dependant variable

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42)

# %% [markdown]
# ## Scaling Fit & Transform

# %%
from sklearn.preprocessing import StandardScaler # https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html

scaler = StandardScaler()
scaler.fit(X_train)

def scale_input(X):
    return scaler.transform(X)

# Notice how the fit is ONLY on the training data
x_train = scale_input(X_train)
x_test = scale_input(X_test)

# %% [markdown]
# # Scikit

# %% [markdown]
# ## Decision Tree Classifier

# %% [markdown]
# ### Training

# %%
from sklearn.tree import DecisionTreeClassifier

classifier = DecisionTreeClassifier(random_state=42, max_depth=5)
classifier.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35564/2509242103.py in <module>
#       2
#       3 classifier = DecisionTreeClassifier(random_state=42, max_depth=5)
# ----> 4 classifier.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# ### Validation

# %%
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(y_test, classifier.predict(x_test))
sns.heatmap(conf_mat, square=True, annot=True, cmap='viridis', fmt='d', cbar=True)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
from sklearn.tree import export_graphviz
from sklearn.tree import plot_tree

# get feature names
feature_names = df.drop(['id', 'diagnosis'], axis=1).columns

# dot_data = export_graphviz(classifier, filled=True, rounded=True,
#                            class_names=['Malignant', 'Benign'],
#                            out_file=None)
plt.figure(figsize=(40, 20))
plot_tree(classifier, filled=True, rounded=True, feature_names=feature_names)
plt.show()

# %% [markdown]
# ## Random Forest Classification

# %% [markdown]
# ### Training

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=5, random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ### Validation

# %%
conf_mat = confusion_matrix(y_test, classifier.predict(x_test))
sns.heatmap(conf_mat, square=True, annot=True,
            cmap='viridis', fmt='d', cbar=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## K-Nearest Neighbors

# %% [markdown]
# ### Initial Dataset

# %%
from sklearn.neighbors import NearestNeighbors

def get_neighbors(X, x_test, n_neighbors=5):
    '''
    X: training data
    x_test: test data
    n_neighbors: number of neighbors to return
    '''
    nbrs = NearestNeighbors(n_neighbors=n_neighbors, algorithm='ball_tree').fit(X)
    distances, indices = nbrs.kneighbors(x_test)
    return distances, indices

def get_predictions(X, y, x_test, n_neighbors=5):
    distances, indices = get_neighbors(X, x_test, n_neighbors)
    predictions = []
    for ind in indices:
        # print(y[ind])
        # print(y[ind].mean())
        predictions.append(round(y[ind].mean()))
    return predictions

# get_predictions(x_train, y_train, x_test, n_neighbors=5)

# %%
conf_mat = confusion_matrix(y_test, get_predictions(x_train, y_train, x_test, n_neighbors=5))
sns.heatmap(conf_mat, square=True, annot=True, cmap='viridis', fmt='d', cbar=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Support Vector Machines

# %% [markdown]
# ### Training

# %%
from sklearn import svm

model = svm.SVC(kernel='rbf', gamma=0.1, C=10)
model.fit(x_train, y_train)
# Out:
# SVC(C=10, gamma=0.1)

# %%
conf_mat = confusion_matrix(y_test, model.predict(x_test))
sns.heatmap(conf_mat, square=True, annot=True, fmt='d', cbar=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Naive Bayes

# %% [markdown]
# ### Training

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ### Predictions

# %%
conf_mat = confusion_matrix(y_test, model.predict(x_test))
sns.heatmap(conf_mat, square=True, annot=True, fmt='d', cbar=True)
# Out:
# <AxesSubplot:>
